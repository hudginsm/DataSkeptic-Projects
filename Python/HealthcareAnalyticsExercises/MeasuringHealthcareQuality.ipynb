# %%
import pandas as pd
FilePath = r"/home/dataskeptic/Downloads/qip1-cmpl.csv"
df = pd.read_csv(FilePath)

print('Number of rows: ' + str(df.shape[0]))
print('Number of columns: ' + str(df.shape[1]))
print(df.head(n=5))
print(df.columns)
# Out:
# Number of rows: 7625
# Number of columns: 143
#                                        Facility Name  \
# 0             032302 MARICOPA MEDICAL CTR - DIALYSIS
# 1  032314 PHOENIX CHILDRENS HOSPITAL- DIALYSIS CE...
# 2                    032315 GILA RIVER DIALYSIS EAST
# 3  032316 Banner University Medical Center Pediat...
# 4      032503 PHOENIX ARTIFICIAL KIDNEY CENTER (FMC)
#
#    CMS Certification Number (CCN) Alternate CCN                      Address  \
# 0                           32302        030022          2525 E ROOSEVELT ST
# 1                           32314        033302  1920 E CAMBRIDGE RD STE 102
# 2                           32315        031308           565 W SEED FARM RD
# 3                           32316        030064                PO BOX 245148
# 4                           32503             -      13090 N 94TH DR STE 100
#
#       City State  Zip Code  Network Long-term Catheter Measure Score  \
# ...
